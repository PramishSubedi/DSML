# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.5.2'

# %%
my_list = [1, 2, 3, 4]
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
your_list = my_list * 2
print(your_list)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
array1 = np.array([1, 2, 3, 4])
print(array1)
print(type(array1))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
# multiplying array1 by 2

multiply_array1_by_2 = array1 * 2
print(multiply_array1_by_2)
# Out:
# [2 4 6 8]
